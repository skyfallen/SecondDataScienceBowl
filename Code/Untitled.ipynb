# %%
import sys
sys.version
# Out:
# '2.7.3 (default, Mar 11 2013, 22:38:13) \n[GCC 4.4.7 20120313 (Red Hat 4.4.7-3)]'

# %%
# Start with importing necessary packages
import dicom
import os
import numpy
from matplotlib import pyplot, cm

# %%
# Search for all DCM
PathDicom = "/storage/hpc_dmytro/Kaggle/SDSB/images/raw/train/"
lstFilesDCM = []  # create an empty list
for dirName, subdirList, fileList in os.walk(PathDicom):
    for filename in fileList:
        if ".dcm" in filename.lower():  # check whether the file's DICOM
            lstFilesDCM.append(os.path.join(dirName,filename))

# %%
print lstFilesDCM

# %%
import pandas as pd
import numpy as np
train = pd.read_csv('train.csv')
def doHist(data):
    h = np.zeros(600)
    for j in np.ceil(data.values).astype(int):
        h[j:] += 1
    h /= len(data)
    return h
hSystole = doHist(train.Systole)
hDiastole = doHist(train.Diastole)
sub = pd.read_csv('sample_submission_validate.csv', index_col='Id')
N = len(sub)//2
X = np.zeros((2*N,600))
for i in range(N):
    X[2*i,:] = hDiastole
    X[2*i+1,:] = hSystole
sub[sub.columns] = X
sub.to_csv('submission.csv')
